# %%
import serpent
import pdb
# Out:
# /home/zoe/Documents/pyne/pyne/serpent.py:13: QAWarning: serpent is not yet QA compliant.
#   warn(__name__ + " is not yet QA compliant.", QAWarning)

# %%
serpent.parse_dep("deptest_dep.m")
# Out:
# /home/zoe/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /home/zoe/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# {'np': <module 'numpy' from '/home/zoe/anaconda3/lib/python3.7/site-packages/numpy/__init__.py'>,
#  '__warningregistry__': {'version': 893},
#  'Material': pyne.material.Material,
#  'ZAI': array([922350, 922380, 942390, 942400, 942410, 942420, 952410, 952440,
#         952450, 360850, 380900, 471101, 551370, 541350, 621490, 621510,
#            666,      0]),
#  'NAMES': ['U235            U238            Pu239           Pu240           Pu241           Pu242           Am241           Am244           Am245           Kr85            Sr90            Ag110m          Cs137           Xe135           Sm149           Sm151           lost            total           '],
#  'i922350': 1,
#  'i922380': 2,
# ...
